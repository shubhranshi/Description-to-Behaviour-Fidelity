# %%
## import libraries

import itertools
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

from sklearn import preprocessing
# %matplotlib inline

# %%
## uploading csv files on drive (to avoid uploading on colab in every session)

from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## 20247

# %%
print(" XLNet - Testing set performance - 20K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV1_N20k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV2_N20k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV3_N20k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV4_N20k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV5_N20k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV1_N20k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV2_N20k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV3_N20k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV4_N20k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV5_N20k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV1_N20k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV2_N20k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV3_N20k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV4_N20k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV5_N20k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  XLNet - Testing set performance - 20K
#
# ------ F1 ------
#  CV1 : 0.4958
#  CV2 : 0.4995
#  CV3 : 0.5403
#  CV4 : 0.5215
#  CV5 : 0.5105
# Average : 0.5135
#
# ------ F1 Micro ------
#   Camera    : 0.8860
#   Location  : 0.8679
#   Microphone: 0.9182
#   Contacts  : 0.8755
#   Storage   : 0.7532
#   Phone     : 0.8412
#   SMS       : 0.9830
#   Call_Log  : 0.9986
#   Calendar  : 0.9749
#
#  CV1 : 0.8998
#  CV2 : 0.8994
#  CV3 : 0.8988
#  CV4 : 0.8998
#  CV5 : 0.9013
# Average : 0.8998
#
# ------ ROC-AUC ------
#   Camera    : 0.8309
#   Location  : 0.7764
#   Microphone: 0.8290
#   Contacts  : 0.7994
#   Storage   : 0.7647
#   Phone     : 0.7514
#   SMS       : 0.8459
#   Call_Log  : 0.8748
#   Calendar  : 0.8464
#
#  CV1 : 0.8192
#  CV2 : 0.8117
#  CV3 : 0.8222
#  CV4 : 0.8078
#  CV5 : 0.8052
# Average : 0.8132

# %% [markdown]
# ## 72684

# %%
print(" XLNet - Testing set performance - 72K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV1_N72k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV2_N72k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV3_N72k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV4_N72k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV5_N72k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV1_N72k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV2_N72k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV3_N72k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV4_N72k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV5_N72k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV1_N72k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV2_N72k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV3_N72k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV4_N72k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV5_N72k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  XLNet - Testing set performance - 72K
#
# ------ F1 ------
#  CV1 : 0.4890
#  CV2 : 0.5311
#  CV3 : 0.5590
#  CV4 : 0.5254
#  CV5 : 0.5178
# Average : 0.5244
#
# ------ F1 Micro ------
#   Camera    : 0.8962
#   Location  : 0.8699
#   Microphone: 0.9228
#   Contacts  : 0.8783
#   Storage   : 0.7599
#   Phone     : 0.8577
#   SMS       : 0.9935
#   Call_Log  : 0.9985
#   Calendar  : 0.9728
#
#  CV1 : 0.9040
#  CV2 : 0.9018
#  CV3 : 0.9092
#  CV4 : 0.9074
#  CV5 : 0.9051
# Average : 0.9055
#
# ------ ROC-AUC ------
#   Camera    : 0.8455
#   Location  : 0.7741
#   Microphone: 0.8285
#   Contacts  : 0.8007
#   Storage   : 0.7724
#   Phone     : 0.7601
#   SMS       : 0.8254
#   Call_Log  : 0.9074
#   Calendar  : 0.8434
#
#  CV1 : 0.8054
#  CV2 : 0.8248
#  CV3 : 0.8183
#  CV4 : 0.8240
#  CV5 : 0.8150
# Average : 0.8175

# %% [markdown]
# ## 121655

# %%
print(" XLNet - Testing set performance - 121K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV1_N121k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV2_N121k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV3_N121k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV4_N121k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1_CV5_N121k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV1_N121k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV2_N121k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV3_N121k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV4_N121k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/F1Mic_CV5_N121k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV1_N121k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV2_N121k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV3_N121k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV4_N121k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ROC_CV5_N121k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  XLNet - Testing set performance - 121K
#
# ------ F1 ------
#  CV1 : 0.6796
#  CV2 : 0.6955
#  CV3 : 0.6564
#  CV4 : 0.6360
#  CV5 : 0.6340
# Average : 0.6603
#
# ------ F1 Micro ------
#   Camera    : 0.9151
#   Location  : 0.8954
#   Microphone: 0.9445
#   Contacts  : 0.9054
#   Storage   : 0.7964
#   Phone     : 0.8819
#   SMS       : 0.9965
#   Call_Log  : 0.9994
#   Calendar  : 0.9839
#
#  CV1 : 0.9254
#  CV2 : 0.9244
#  CV3 : 0.9270
#  CV4 : 0.9244
#  CV5 : 0.9202
# Average : 0.9243
#
# ------ ROC-AUC ------
#   Camera    : 0.8708
#   Location  : 0.8055
#   Microphone: 0.8890
#   Contacts  : 0.8351
#   Storage   : 0.8041
#   Phone     : 0.7969
#   SMS       : 0.9586
#   Call_Log  : 0.9491
#   Calendar  : 0.9325
#
#  CV1 : 0.8842
#  CV2 : 0.8732
#  CV3 : 0.8792
#  CV4 : 0.8679
#  CV5 : 0.8518
# Average : 0.8713

# %% [markdown]
# # ACNET

# %% [markdown]
# ## 20247

# %%
print(" XLNet - ACNET performance - 20K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV1_N20k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV2_N20k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV3_N20k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV4_N20k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV5_N20k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV1_N20k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV2_N20k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV3_N20k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV4_N20k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV5_N20k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV1_N20k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV2_N20k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV3_N20k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV4_N20k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV5_N20k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  XLNet - ACNET performance - 20K
#
# ------ F1 ------
#  CV1 : 0.5080
#  CV2 : 0.7612
#  CV3 : 0.7773
#  CV4 : 0.6431
#  CV5 : 0.6781
# Average : 0.6735
#
# ------ F1 Micro ------
#  CV1 : 0.7918
#  CV2 : 0.8976
#  CV3 : 0.9089
#  CV4 : 0.8540
#  CV5 : 0.8656
# Average : 0.8636
#
# ------ ROC-AUC ------
#  CV1 : 0.7128
#  CV2 : 0.8769
#  CV3 : 0.8851
#  CV4 : 0.8191
#  CV5 : 0.8369
# Average : 0.8261

# %% [markdown]
# ## 72684

# %%
print(" XLNet - ACNET performance - 72K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV1_N72k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV2_N72k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV3_N72k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV4_N72k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV5_N72k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV1_N72k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV2_N72k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV3_N72k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV4_N72k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV5_N72k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV1_N72k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV2_N72k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV3_N72k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV4_N72k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV5_N72k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  XLNet - ACNET performance - 72K
#
# ------ F1 ------
#  CV1 : 0.6385
#  CV2 : 0.7033
#  CV3 : 0.7309
#  CV4 : 0.7020
#  CV5 : 0.6863
# Average : 0.6922
#
# ------ F1 Micro ------
#  CV1 : 0.8519
#  CV2 : 0.8753
#  CV3 : 0.8796
#  CV4 : 0.8708
#  CV5 : 0.8637
# Average : 0.8683
#
# ------ ROC-AUC ------
#  CV1 : 0.8134
#  CV2 : 0.8456
#  CV3 : 0.8544
#  CV4 : 0.8495
#  CV5 : 0.8385
# Average : 0.8403

# %% [markdown]
# ## 121655

# %%
print(" XLNet - ACNET performance - 121K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV1_N121k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV2_N121k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV3_N121k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV4_N121k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1_CV5_N121k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV1_N121k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV2_N121k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV3_N121k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV4_N121k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_F1Mic_CV5_N121k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV1_N121k_XLNet.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV2_N121k_XLNet.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV3_N121k_XLNet.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV4_N121k_XLNet.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_XLNet/ACNET_ROC_CV5_N121k_XLNet.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  XLNet - ACNET performance - 121K
#
# ------ F1 ------
#  CV1 : 0.6953
#  CV2 : 0.7005
#  CV3 : 0.6583
#  CV4 : 0.6885
#  CV5 : 0.6331
# Average : 0.6751
#
# ------ F1 Micro ------
#  CV1 : 0.8696
#  CV2 : 0.8673
#  CV3 : 0.8465
#  CV4 : 0.8665
#  CV5 : 0.8512
# Average : 0.8602
#
# ------ ROC-AUC ------
#  CV1 : 0.8388
#  CV2 : 0.8414
#  CV3 : 0.8269
#  CV4 : 0.8352
#  CV5 : 0.8105
# Average : 0.8306
