# %%
## import libraries

import itertools
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

from sklearn import preprocessing
# %matplotlib inline

# %%
## uploading csv files on drive (to avoid uploading on colab in every session)

from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## 20247

# %%
print(" Text CNN - Testing set performance - 20K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV1_N20k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV2_N20k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV3_N20k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV4_N20k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV5_N20k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV1_N20k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV2_N20k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV3_N20k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV4_N20k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV5_N20k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV1_N20k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV2_N20k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV3_N20k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV4_N20k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV5_N20k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  Text CNN - Testing set performance - 20K
#
# ------ F1 ------
#  CV1 : 0.4923
#  CV2 : 0.4919
#  CV3 : 0.4855
#  CV4 : 0.4992
#  CV5 : 0.4914
# Average : 0.4921
#
# ------ F1 Micro ------
#   Camera    : 0.8964
#   Location  : 0.8680
#   Microphone: 0.9198
#   Contacts  : 0.8853
#   Storage   : 0.7780
#   Phone     : 0.8513
#   SMS       : 0.9895
#   Call_Log  : 0.9986
#   Calendar  : 0.9774
#
#  CV1 : 0.9098
#  CV2 : 0.9045
#  CV3 : 0.9076
#  CV4 : 0.9087
#  CV5 : 0.9050
# Average : 0.9071
#
# ------ ROC-AUC ------
#   Camera    : 0.8436
#   Location  : 0.7757
#   Microphone: 0.8189
#   Contacts  : 0.8080
#   Storage   : 0.7863
#   Phone     : 0.7596
#   SMS       : 0.8486
#   Call_Log  : 0.8700
#   Calendar  : 0.8222
#
#  CV1 : 0.8072
#  CV2 : 0.8078
#  CV3 : 0.8148
#  CV4 : 0.8247
#  CV5 : 0.8193
# Average : 0.8148

# %% [markdown]
# ## 72684

# %%
print(" Text CNN - Testing set performance - 72K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV1_N72k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV2_N72k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV3_N72k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV4_N72k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV5_N72k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV1_N72k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV2_N72k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV3_N72k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV4_N72k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV5_N72k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV1_N72k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV2_N72k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV3_N72k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV4_N72k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV5_N72k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  Text CNN - Testing set performance - 72K
#
# ------ F1 ------
#  CV1 : 0.4814
#  CV2 : 0.5116
#  CV3 : 0.5199
#  CV4 : 0.4989
#  CV5 : 0.5246
# Average : 0.5073
#
# ------ F1 Micro ------
#   Camera    : 0.8878
#   Location  : 0.8641
#   Microphone: 0.9160
#   Contacts  : 0.8814
#   Storage   : 0.7765
#   Phone     : 0.8569
#   SMS       : 0.9874
#   Call_Log  : 0.9990
#   Calendar  : 0.9766
#
#  CV1 : 0.9033
#  CV2 : 0.9074
#  CV3 : 0.9067
#  CV4 : 0.9024
#  CV5 : 0.9056
# Average : 0.9051
#
# ------ ROC-AUC ------
#   Camera    : 0.8428
#   Location  : 0.7646
#   Microphone: 0.8226
#   Contacts  : 0.7878
#   Storage   : 0.7849
#   Phone     : 0.7632
#   SMS       : 0.7980
#   Call_Log  : 0.6625
#   Calendar  : 0.8363
#
#  CV1 : 0.7331
#  CV2 : 0.8183
#  CV3 : 0.7783
#  CV4 : 0.8227
#  CV5 : 0.7714
# Average : 0.7847

# %% [markdown]
# ## 121655

# %%
print(" Text CNN - Testing set performance - 121K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV1_N121k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV2_N121k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV3_N121k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV4_N121k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1_CV5_N121k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV1_N121k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV2_N121k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV3_N121k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV4_N121k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/F1Mic_CV5_N121k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV1_N121k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV2_N121k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV3_N121k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV4_N121k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ROC_CV5_N121k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  Text CNN - Testing set performance - 121K
#
# ------ F1 ------
#  CV1 : 0.4955
#  CV2 : 0.5053
#  CV3 : 0.5058
#  CV4 : 0.5101
#  CV5 : 0.4985
# Average : 0.5030
#
# ------ F1 Micro ------
#   Camera    : 0.8932
#   Location  : 0.8661
#   Microphone: 0.9260
#   Contacts  : 0.8883
#   Storage   : 0.7693
#   Phone     : 0.8434
#   SMS       : 0.9901
#   Call_Log  : 0.9981
#   Calendar  : 0.9785
#
#  CV1 : 0.9070
#  CV2 : 0.9055
#  CV3 : 0.9033
#  CV4 : 0.9038
#  CV5 : 0.9100
# Average : 0.9059
#
# ------ ROC-AUC ------
#   Camera    : 0.8376
#   Location  : 0.7669
#   Microphone: 0.8170
#   Contacts  : 0.7954
#   Storage   : 0.7785
#   Phone     : 0.7639
#   SMS       : 0.5630
#   Call_Log  : 0.6646
#   Calendar  : 0.8143
#
#  CV1 : 0.7758
#  CV2 : 0.7280
#  CV3 : 0.7265
#  CV4 : 0.7323
#  CV5 : 0.8157
# Average : 0.7557

# %% [markdown]
# # ACNET

# %% [markdown]
# ## 20247

# %%
print(" Text CNN - ACNET performance - 20K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV1_N20k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV2_N20k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV3_N20k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV4_N20k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV5_N20k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV1_N20k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV2_N20k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV3_N20k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV4_N20k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV5_N20k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV1_N20k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV2_N20k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV3_N20k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV4_N20k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV5_N20k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  Text CNN - ACNET performance - 20K
#
# ------ F1 ------
#  CV1 : 0.4962
#  CV2 : 0.5047
#  CV3 : 0.5058
#  CV4 : 0.5228
#  CV5 : 0.4884
# Average : 0.5036
#
# ------ F1 Micro ------
#  CV1 : 0.7968
#  CV2 : 0.7933
#  CV3 : 0.7903
#  CV4 : 0.8012
#  CV5 : 0.7804
# Average : 0.7924
#
# ------ ROC-AUC ------
#  CV1 : 0.7416
#  CV2 : 0.7420
#  CV3 : 0.7459
#  CV4 : 0.7459
#  CV5 : 0.7231
# Average : 0.7397

# %% [markdown]
# ## 72684

# %%
print(" Text CNN - ACNET performance - 72K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV1_N72k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV2_N72k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV3_N72k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV4_N72k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV5_N72k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV1_N72k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV2_N72k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV3_N72k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV4_N72k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV5_N72k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV1_N72k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV2_N72k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV3_N72k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV4_N72k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV5_N72k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  Text CNN - ACNET performance - 72K
#
# ------ F1 ------
#  CV1 : 0.5155
#  CV2 : 0.5121
#  CV3 : 0.5022
#  CV4 : 0.5218
#  CV5 : 0.5121
# Average : 0.5127
#
# ------ F1 Micro ------
#  CV1 : 0.8125
#  CV2 : 0.7984
#  CV3 : 0.8098
#  CV4 : 0.8010
#  CV5 : 0.8078
# Average : 0.8059
#
# ------ ROC-AUC ------
#  CV1 : 0.6716
#  CV2 : 0.7351
#  CV3 : 0.7015
#  CV4 : 0.7075
#  CV5 : 0.7510
# Average : 0.7133

# %% [markdown]
# ## 121655

# %%
print(" Text CNN - ACNET performance - 121K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV1_N121k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV2_N121k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV3_N121k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV4_N121k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1_CV5_N121k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV1_N121k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV2_N121k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV3_N121k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV4_N121k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_F1Mic_CV5_N121k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV1_N121k_TCNN.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV2_N121k_TCNN.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV3_N121k_TCNN.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV4_N121k_TCNN.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_TextCNN/ACNET_ROC_CV5_N121k_TCNN.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  Text CNN - ACNET performance - 121K
#
# ------ F1 ------
#  CV1 : 0.4998
#  CV2 : 0.4961
#  CV3 : 0.4927
#  CV4 : 0.4966
#  CV5 : 0.5162
# Average : 0.5003
#
# ------ F1 Micro ------
#  CV1 : 0.8105
#  CV2 : 0.7926
#  CV3 : 0.8012
#  CV4 : 0.7885
#  CV5 : 0.8127
# Average : 0.8011
#
# ------ ROC-AUC ------
#  CV1 : 0.6994
#  CV2 : 0.7085
#  CV3 : 0.7007
#  CV4 : 0.6683
#  CV5 : 0.7321
# Average : 0.7018
