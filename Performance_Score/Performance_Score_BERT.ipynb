# %%
## import libraries

import itertools
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

from sklearn import preprocessing
# %matplotlib inline

# %%
## uploading csv files on drive (to avoid uploading on colab in every session)

from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ## 20247

# %%
print(" BERT - Testing set performance - 20K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV1_N20k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV2_N20k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV3_N20k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV4_N20k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV5_N20k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV1_N20k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV2_N20k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV3_N20k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV4_N20k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV5_N20k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV1_N20k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV2_N20k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV3_N20k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV4_N20k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV5_N20k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  BERT - Testing set performance - 20K
#
# ------ F1 ------
#  CV1 : 0.4974
#  CV2 : 0.5088
#  CV3 : 0.5010
#  CV4 : 0.4992
#  CV5 : 0.4785
# Average : 0.4970
#
# ------ F1 Micro ------
#   Camera    : 0.8857
#   Location  : 0.8563
#   Microphone: 0.9147
#   Contacts  : 0.8766
#   Storage   : 0.7660
#   Phone     : 0.8503
#   SMS       : 0.9801
#   Call_Log  : 0.9983
#   Calendar  : 0.9779
#
#  CV1 : 0.8979
#  CV2 : 0.9036
#  CV3 : 0.9034
#  CV4 : 0.8987
#  CV5 : 0.8997
# Average : 0.9007
#
# ------ ROC-AUC ------
#   Camera    : 0.8258
#   Location  : 0.7680
#   Microphone: 0.8252
#   Contacts  : 0.8026
#   Storage   : 0.7737
#   Phone     : 0.7482
#   SMS       : 0.7570
#   Call_Log  : 0.7919
#   Calendar  : 0.8074
#
#  CV1 : 0.7868
#  CV2 : 0.7868
#  CV3 : 0.7937
#  CV4 : 0.7868
#  CV5 : 0.7903
# Average : 0.7889

# %% [markdown]
# ## 72684

# %%
print(" BERT - Testing set performance - 72K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV1_N72k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV2_N72k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV3_N72k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV4_N72k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV5_N72k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV1_N72k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV2_N72k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV3_N72k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV4_N72k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV5_N72k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV1_N72k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV2_N72k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV3_N72k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV4_N72k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV5_N72k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  BERT - Testing set performance - 72K
#
# ------ F1 ------
#  CV1 : 0.4918
#  CV2 : 0.5194
#  CV3 : 0.5193
#  CV4 : 0.5241
#  CV5 : 0.5149
# Average : 0.5139
#
# ------ F1 Micro ------
#   Camera    : 0.8864
#   Location  : 0.8707
#   Microphone: 0.9221
#   Contacts  : 0.8819
#   Storage   : 0.7736
#   Phone     : 0.8568
#   SMS       : 0.9960
#   Call_Log  : 0.9986
#   Calendar  : 0.9772
#
#  CV1 : 0.9117
#  CV2 : 0.9053
#  CV3 : 0.9075
#  CV4 : 0.9056
#  CV5 : 0.9050
# Average : 0.9070
#
# ------ ROC-AUC ------
#   Camera    : 0.8392
#   Location  : 0.7779
#   Microphone: 0.8328
#   Contacts  : 0.7988
#   Storage   : 0.7818
#   Phone     : 0.7640
#   SMS       : 0.7427
#   Call_Log  : 0.8797
#   Calendar  : 0.8003
#
#  CV1 : 0.8186
#  CV2 : 0.7885
#  CV3 : 0.7944
#  CV4 : 0.8081
#  CV5 : 0.7999
# Average : 0.8019

# %% [markdown]
# ## 121655

# %%
print(" BERT - Testing set performance - 121K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV1_N121k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV2_N121k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV3_N121k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV4_N121k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1_CV5_N121k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV1_N121k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV2_N121k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV3_N121k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV4_N121k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/F1Mic_CV5_N121k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV1_N121k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV2_N121k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV3_N121k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV4_N121k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ROC_CV5_N121k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")

print("  Camera    : {0:.4f}".format((eval_acc_1[0] + eval_acc_2[0] + eval_acc_3[0] + eval_acc_4[0] + eval_acc_5[0]) / 5))
print("  Location  : {0:.4f}".format((eval_acc_1[1] + eval_acc_2[1] + eval_acc_3[1] + eval_acc_4[1] + eval_acc_5[1]) / 5))
print("  Microphone: {0:.4f}".format((eval_acc_1[2] + eval_acc_2[2] + eval_acc_3[2] + eval_acc_4[2] + eval_acc_5[2]) / 5))
print("  Contacts  : {0:.4f}".format((eval_acc_1[3] + eval_acc_2[3] + eval_acc_3[3] + eval_acc_4[3] + eval_acc_5[3]) / 5))
print("  Storage   : {0:.4f}".format((eval_acc_1[4] + eval_acc_2[4] + eval_acc_3[4] + eval_acc_4[4] + eval_acc_5[4]) / 5))
print("  Phone     : {0:.4f}".format((eval_acc_1[5] + eval_acc_2[5] + eval_acc_3[5] + eval_acc_4[5] + eval_acc_5[5]) / 5))
print("  SMS       : {0:.4f}".format((eval_acc_1[6] + eval_acc_2[6] + eval_acc_3[6] + eval_acc_4[6] + eval_acc_5[6]) / 5))
print("  Call_Log  : {0:.4f}".format((eval_acc_1[7] + eval_acc_2[7] + eval_acc_3[7] + eval_acc_4[7] + eval_acc_5[7]) / 5))
print("  Calendar  : {0:.4f}".format((eval_acc_1[8] + eval_acc_2[8] + eval_acc_3[8] + eval_acc_4[8] + eval_acc_5[8]) / 5))

print("")

print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  BERT - Testing set performance - 121K
#
# ------ F1 ------
#  CV1 : 0.5407
#  CV2 : 0.5249
#  CV3 : 0.5032
#  CV4 : 0.5281
#  CV5 : 0.5225
# Average : 0.5239
#
# ------ F1 Micro ------
#   Camera    : 0.8928
#   Location  : 0.8755
#   Microphone: 0.9268
#   Contacts  : 0.8901
#   Storage   : 0.7729
#   Phone     : 0.8608
#   SMS       : 0.9962
#   Call_Log  : 0.9990
#   Calendar  : 0.9785
#
#  CV1 : 0.9093
#  CV2 : 0.9141
#  CV3 : 0.9115
#  CV4 : 0.9100
#  CV5 : 0.9065
# Average : 0.9103
#
# ------ ROC-AUC ------
#   Camera    : 0.8438
#   Location  : 0.7833
#   Microphone: 0.8306
#   Contacts  : 0.8038
#   Storage   : 0.7847
#   Phone     : 0.7676
#   SMS       : 0.7131
#   Call_Log  : 0.8308
#   Calendar  : 0.7783
#
#  CV1 : 0.8005
#  CV2 : 0.7933
#  CV3 : 0.7947
#  CV4 : 0.7991
#  CV5 : 0.7768
# Average : 0.7929

# %% [markdown]
# # ACNET

# %% [markdown]
# ## 20247

# %%
print(" BERT - ACNET performance - 20K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV1_N20k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV2_N20k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV3_N20k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV4_N20k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV5_N20k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV1_N20k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV2_N20k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV3_N20k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV4_N20k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV5_N20k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV1_N20k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV2_N20k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV3_N20k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV4_N20k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV5_N20k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  BERT - ACNET performance - 20K
#
# ------ F1 ------
#  CV1 : 0.4520
#  CV2 : 0.7821
#  CV3 : 0.7738
#  CV4 : 0.7930
#  CV5 : 0.7647
# Average : 0.7131
#
# ------ F1 Micro ------
#  CV1 : 0.7563
#  CV2 : 0.8976
#  CV3 : 0.9008
#  CV4 : 0.9075
#  CV5 : 0.9004
# Average : 0.8725
#
# ------ ROC-AUC ------
#  CV1 : 0.6878
#  CV2 : 0.8828
#  CV3 : 0.8793
#  CV4 : 0.8906
#  CV5 : 0.8739
# Average : 0.8429

# %% [markdown]
# ## 72684

# %%
print(" BERT - ACNET performance - 72K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV1_N72k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV2_N72k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV3_N72k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV4_N72k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV5_N72k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV1_N72k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV2_N72k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV3_N72k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV4_N72k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV5_N72k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV1_N72k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV2_N72k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV3_N72k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV4_N72k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV5_N72k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  BERT - ACNET performance - 72K
#
# ------ F1 ------
#  CV1 : 0.4999
#  CV2 : 0.8002
#  CV3 : 0.7995
#  CV4 : 0.7870
#  CV5 : 0.8000
# Average : 0.7373
#
# ------ F1 Micro ------
#  CV1 : 0.8003
#  CV2 : 0.9103
#  CV3 : 0.9081
#  CV4 : 0.9077
#  CV5 : 0.9037
# Average : 0.8860
#
# ------ ROC-AUC ------
#  CV1 : 0.7103
#  CV2 : 0.8917
#  CV3 : 0.8875
#  CV4 : 0.8848
#  CV5 : 0.8936
# Average : 0.8536

# %% [markdown]
# ## 121655

# %%
print(" BERT - ACNET performance - 121K")
print("")

## F1
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV1_N121k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV2_N121k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV3_N121k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV4_N121k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1_CV5_N121k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

################################################################################################

## F1-micro
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV1_N121k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV2_N121k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV3_N121k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV4_N121k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_F1Mic_CV5_N121k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ F1 Micro ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")

###################################################################################################

## ROC-AUC
eval_acc_1 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV1_N121k_Bert.npy")
avg_score_1 = (np.sum(eval_acc_1, dtype = np.float32)) / 9
eval_acc_2 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV2_N121k_Bert.npy")
avg_score_2 = (np.sum(eval_acc_2, dtype = np.float32)) / 9
eval_acc_3 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV3_N121k_Bert.npy")
avg_score_3 = (np.sum(eval_acc_3, dtype = np.float32)) / 9
eval_acc_4 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV4_N121k_Bert.npy")
avg_score_4 = (np.sum(eval_acc_4, dtype = np.float32)) / 9
eval_acc_5 = np.load("/content/drive/MyDrive/Performance_Score_Bert/ACNET_ROC_CV5_N121k_Bert.npy")
avg_score_5 = (np.sum(eval_acc_5, dtype = np.float32)) / 9

print("------ ROC-AUC ------")
print(" CV1 : {0:.4f}".format(avg_score_1))
print(" CV2 : {0:.4f}".format(avg_score_2))
print(" CV3 : {0:.4f}".format(avg_score_3))
print(" CV4 : {0:.4f}".format(avg_score_4))
print(" CV5 : {0:.4f}".format(avg_score_5))
print("Average : {0:.4f}".format( (avg_score_1 + avg_score_2 + avg_score_3 + avg_score_4 + avg_score_5) / 5))
print(" ")
# Out:
#  BERT - ACNET performance - 121K
#
# ------ F1 ------
#  CV1 : 0.5056
#  CV2 : 0.8348
#  CV3 : 0.8278
#  CV4 : 0.8023
#  CV5 : 0.8008
# Average : 0.7543
#
# ------ F1 Micro ------
#  CV1 : 0.7915
#  CV2 : 0.9209
#  CV3 : 0.9245
#  CV4 : 0.9093
#  CV5 : 0.9086
# Average : 0.8910
#
# ------ ROC-AUC ------
#  CV1 : 0.7091
#  CV2 : 0.9096
#  CV3 : 0.9052
#  CV4 : 0.8943
#  CV5 : 0.8918
# Average : 0.8620
